# %%
import matplotlib.pyplot as plt

# Data for the losses from your image
epochs = [1, 2, 3, 4]
training_loss = [0.138200, 0.114700, 0.086300, 0.077000]
validation_loss = [0.130062, 0.125268, 0.127347, 0.130764]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(epochs, training_loss, label="Training Loss", marker='o', color='blue')
plt.plot(epochs, validation_loss, label="Validation Loss", marker='o', color='green')

# Adding titles and labels
plt.title('Training and Validation Loss over Epochs for BART-Large')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Adding a legend
plt.legend()

# Displaying the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for PEGASUS model (from the image)
steps = [200, 400, 600, 800]
training_loss = [0.111400, 0.107600, 0.107400, 0.104800]
validation_loss = [0.398067, 0.401300, 0.400770, 0.401076]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(steps, training_loss, label="Training Loss", marker='o', color='blue')
plt.plot(steps, validation_loss, label="Validation Loss", marker='o', color='green')

# Adding titles and labels
plt.title('Training and Validation Loss over Steps for PEGASUS Model')
plt.xlabel('Steps')
plt.ylabel('Loss')

# Adding a legend
plt.legend()

# Displaying the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the new image (Steps, Training Loss, Validation Loss)
steps = [200, 400, 600, 800, 1000]
training_loss = [4.288600, 0.136700, 0.122700, 0.115300, 0.114500]
validation_loss = [0.830652, 0.413974, 0.401870, 0.399384, 0.398232]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(steps, training_loss, label="Training Loss", marker='o', color='blue')
plt.plot(steps, validation_loss, label="Validation Loss", marker='o', color='green')

# Adding titles and labels
plt.title('Training and Validation Loss over Steps for PEGASUS Model')
plt.xlabel('Steps')
plt.ylabel('Loss')

# Adding a legend
plt.legend()

# Displaying the graph
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the image
epochs = [1, 2, 3, 4]
training_loss = [0.170600, 0.159800, 0.150600, 0.152000]
validation_loss = [0.148698, 0.145588, 0.144718, 0.144686]

# Plot the losses
plt.plot(epochs, training_loss, label='Training Loss', marker='o')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='o')

# Labeling the plot
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses for T5-small Model')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# DISTIL BART MODEL
# ![image.png](data:image/png;base64,...)
